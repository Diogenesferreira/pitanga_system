# %%
import pandas as pd

base = pd.read_csv(fr'db\base_vendas.csv', sep=';', dtype=str encoding='iso-8859-1')

base
# Out:
#      DATA VENDA             NOME      TELEFONE  QTD        PRODUTO  \
# 0    06/09/2024    Matheus Rocha  2.195936e+10    1  COPO RECHEADO
# 1    06/09/2024  Luana Guimaraes  2.196928e+10    1  CAIXA SIMPLES
# 2    06/09/2024    Marco Antonio  2.196935e+10    1  CAIXA SIMPLES
# 3    06/09/2024     Thaina Ramos  2.197400e+10    1  CAIXA SIMPLES
# 4    06/09/2024     Thaina Ramos  2.197400e+10    1  COPO RECHEADO
# ..          ...              ...           ...  ...            ...
# 520  04/02/2024  Gustavo Betzler           NaN    1         COOKIE
# 521  04/02/2024    Antonio Durão           NaN    1         COOKIE
# 522  04/02/2024    Antonio Durão           NaN    1         COOKIE
# 523  04/02/2024  Dayane da Silva           NaN    1        BROWNIE
# 524  04/02/2024     Thaina Ramos           NaN    1        BROWNIE
#
#              SABOR VALOR UNIDADE TOTAL DA COMPRA            STATUS PEDIDO  \
# 0              NaN      R$ 15,00        R$ 15,00                    PAGO
# ...
